# %% [markdown]
# ### Requirements
# Here's what we need you to do:
# <br>Connect and load the csv file
# <br>Split the 'Store-Bike' field into 'Store' and 'Bike'
# <br>Clean up the 'Bike' field to leave just three values in the 'Bike' field (Mountain, Gravel, Road) (help)
# <br>Create two different cuts of the date field: 'quarter' and 'day of month'
# <br>Remove the first 10 orders as they are test values
# <br>Output the data as a csv
#
# <br> Solution Reference: https://github.com/kelly-gilbert/preppin-data-challenge/blob/master/2021/preppin-data-2021-01/preppin-data-2021-01.py

# %%
import pandas as pd

# %%
df = pd.read_csv('2021/input/PD 2021 Wk 1 Input - Bike Sales.csv', 
              parse_dates=['Date'], dayfirst=True)

# %%
df.head()
# Out:
#    Order ID  Customer Age  Bike Value Existing Customer?       Date  \
# 0         1            22         481                 No 2021-04-25
# 1         2            28        1825                 No 2021-01-23
# 2         3            51        1903                 No 2021-07-03
# 3         4            59        1059                 No 2021-01-24
# 4         5            44        1764                Yes 2021-08-12
#
#       Store - Bike
# 0      York - Road
# 1      York - Road
# 2      York - Rood
# 3      York - Road
# 4  York - Mountain

# %%
#Series.str.split(pat=None, n=- 1, expand=False)

df[['Store','Bike']]=df['Store - Bike'].str.split(pat=' - ',expand=True)

# %%
df.groupby("Bike").count()
# Out:
#           Order ID  Customer Age  Bike Value  Existing Customer?  Date  \
# Bike
# Graval          12            12          12                  12    12
# Gravel         177           177         177                 177   177
# Gravle          11            11          11                  11    11
# Mountaen        10            10          10                  10    10
# Mountain       390           390         390                 390   390
# Road           375           375         375                 375   375
# Rood            18            18          18                  18    18
# Rowd             7             7           7                   7     7
#
#           Store - Bike  Store
# Bike
# Graval              12     12
# Gravel             177    177
# Gravle              11     11
# Mountaen            10     10
# Mountain           390    390
# Road               375    375
# Rood                18     18
# Rowd                 7      7

# %%
# clean up the 'Bike' field to leave just three values in the 'Bike' field 
# (Mountain, Gravel, Road)

#dictionary
remap = { 'Graval' : 'Gravel',
          'Gravle' : 'Gravel',
          'Mountaen' : 'Mountain',
          'Rood' : 'Road',
          'Rowd' : 'Road' }

df['Bike'].replace(remap, inplace=True)

# %%
# create two different cuts of the date field: 'quarter' and 'day of month'

df['Quarter'] = df['Date'].dt.quarter
df['Day of Month'] = df['Date'].dt.day

# %%
# remove the first 10 orders as they are test values
df = df.iloc[10:]

# %%
df.head()
# Out:
#    Order ID  Customer Age  Bike Value Existing Customer?       Date  \
# 0         1            22         481                 No 2021-04-25
# 1         2            28        1825                 No 2021-01-23
# 2         3            51        1903                 No 2021-07-03
# 3         4            59        1059                 No 2021-01-24
# 4         5            44        1764                Yes 2021-08-12
#
#       Store - Bike
# 0      York - Road
# 1      York - Road
# 2      York - Rood
# 3      York - Road
# 4  York - Mountain

# %%
# output the data as a csv

col_order = ['Quarter', 'Store', 'Bike', 'Order ID', 'Customer Age',
             'Bike Value', 'Existing Customer?', 'Day of Month']
df[col_order].to_csv('2021/output/output-2021-01.csv', index=False)
